# %% [markdown]
# # Pretty Pictures - Pick an Object

# %% [markdown]
# ---
#
# ## Pick an interesting-to-you (non-Solar System) object.
#
# - ### [Here is a good place for ideas](https://en.wikipedia.org/wiki/Lists_of_astronomical_objects)
# - ### The [Arp catalog](https://en.wikipedia.org/wiki/Atlas_of_Peculiar_Galaxies) is a particularly good list for the more decerning tastes.
# - ### Don't pick a field with just one bright star in it (i.e Sirius).

# %% [markdown]
# ----
# # [The STScI Digitized Sky Survey](https://archive.stsci.edu/cgi-bin/dss_form)
#
# - Download a GIF images of your object
# - Adjust the width and height so that you can see the entire object with a little context
# - Pick the Survey that looks best to you
# - Upload the GIF of your object to this directory
# - Replace the image below with your GIF
#    - Double-click on the cell below
#    - Change the image: `cosmic_distance.png` to your uploaded gif image
#    - Change the name: `Name Here` to the name of your object

# %% [markdown]
# ## My Object: Name Here
#
# <p>
#     <img src="./cosmic_distance.png" width = "600">
# </p>

# %% [markdown]
# ### Due Wed Nov 5 - 1 pm
#
# - `File -> Download as -> HTML (.html)`
# - `upload your .html file to the class Canvas page`
