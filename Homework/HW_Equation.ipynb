# %% [markdown]
# $\LaTeX$ Equation
# =====================

# %% [markdown]
# ## Typeset the following equation:
#
# <p align="center">
# <img src="https://uwashington-astro300.github.io/A300_images/Equation_A22.png" width = "600">
# </p>
#
# ### Paste the $\LaTeX$ code into the following two cells and run them

# %% [raw]
#  ↓ Equation Code Here ↓ - Do not include the $$
# -------------------------------
#
#
#
# -------------------------------

# %% [markdown]
# ### ↓ Equation Here ↓ - Paste between the `$$`
#
# $$ \Large
#
# $$

# %% [markdown]
# ### Your equation should look pretty much exactly as the image above.

# %% [markdown]
# ---
# # Make sure you can login to the Overleaf site.
#
# - ### Go to the [Overleaf](https://www.overleaf.com/login) site and login using your `uw.edu` address.
# - ### Login using the `Log in with SSO` button.
#
# <img src="https://uwashington-astro300.github.io/A300_images/Login_overleaf.png" width = "400">
#
# - ### If you already have an Overleaf account, no need to do this.

# %% [markdown]
# ---
#
# # Start the process to create an account on the Rubin Science Platform
#
# - As UW students, you have Rubin data rights!
# - This will also serve as a Jupyter notebook you can use as long as you are a student here.
# - I will show you how to transfer all your class work to this platform later.
#
# ## Visit the [Rubin signup webpage](https://urldefense.com/v3/__http://ls.st/rsp-signup__;!!K-Hz7m0Vt54!izUFZ07wQqN4rMrWP0Tm4WWoOmFvgWc_oSsANrjJFVb1GjT3mI5E2ViAcF2_-SPElph_uB2ZaFOFcjsXl-ywyjoW$)
#
# - Follow the instructions in the step-by-step instructions section.
# - Choose "University of Washington" as your identity provider and to use your UW email address.
# - Step 8 (account approval) can take a few days.

# %% [markdown]
# ---
# ### Due Mon Nov 24 - 1 pm
# - `File -> Download as -> HTML (.html)`
# - `upload your .html file to the class Canvas page`
