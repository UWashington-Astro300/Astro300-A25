# %% [markdown]
# ---
#
# # Some websites for this assignment:

# %% [markdown]
# - ## [Overleaf](https://www.overleaf.com/login)
#
# - ## [Overleaf Docs and Help](https://www.overleaf.com/learn)
#
# - ## [Latex Symbols](https://en.wikipedia.org/wiki/Wikipedia:LaTeX_symbols)
#
# - ## [Latex draw symbols](http://detexify.kirelabs.org/classify.html)
#
# - ## [Latex wikibook](https://en.wikibooks.org/wiki/LaTeX)
# ---
#
#
# # [AAS Journals](https://journals.aas.org/)
#
#
# # [The SAO/NASA Astrophysics Data System](https://ui.adsabs.harvard.edu/classic-form)

# %% [markdown]
# ---
#
# # `QTables` can output $\LaTeX$ tables

# %%
from astropy.table import QTable
from astropy.io import ascii

# %%
star_table = QTable.read('https://uwashington-astro300.github.io/A300_Data/ObjectList.csv', 
                           format='ascii.csv')

# %%
star_table[0:3]

# %%
ascii.write(star_table, format='latex')

# %% [markdown]
# ---
#
# # [Latex Table Generator](https://www.tablesgenerator.com/)

# %% [markdown]
# ---
#
# # $\LaTeX$ Assignment - (15 pts)

# %% [markdown]
# ## Start with the file: `HW_LaTeX.tex` in Overleaf

# %% [markdown]
# ---
#
# # Required elements:
#
# * Paper must be typeset using the $AAS\TeX$ package
#
# * Aim for a total of 4 pages in length (more is fine).
#
# * At least 500 words of text.
#   * The topic is totally up to you (see below).
#   * Pick a topic you are interested in.
#   * Convince me you spent some time working on the assignment.

# %% [markdown]
# * At least 5 references from ADS.
#   * The references do not need to relate to anything you wrote - just 5 references .
#   * Make sure to `\citep{KEY}` or `\citet{KEY}` the references in your paper.

# %% [markdown]
# * Typeset the equation from your last homework:
#
# <p align="center">
# <img src="https://uwashington-astro300.github.io/A300_images/Equation_A22.png" width = "600">
# </p>
#
# * Typeset one (or more) equation(s) of your choice.

# %% [markdown]
# * Include at least two (more is great) plots/images (they should be related to your topic).
# * One table of at least 2 columns and 2 rows (not the `star_table` from above!).

# %% [markdown]
# ---
#
# ### Need some inspiration? - Here are the topics from the last few Astro 300 classes.
#
# - Stay away from Astro 322 HW and Random Garbage (They got a lousy grade)!

# %% [raw]
# German Poetry             Richard Feynman
# Caterpillars              F1 Racing
# Rogue-Like games          Twenty One Pilots
# The Epic of Gilgamesh     The Art of The Three Point Shot
# Afrikaans Language        Sexual relations in Ancient Greece
# My Cat (3 papers)         J.R.R. Tolkien Stuff (2 papers)
# The Aztecs                Octopath Traveler II
# Doctor Who                Community (The T.V. Show)
# Emo Music                 Godzilla
# Minecraft Mobs            Desk Trinkets
# Octopuses                 The Bee Movie
# Warhammer 40k             Power Rangers
# Futurama                  Magic: the Gathering (2 papers)
# Pride and Prejudice       Competitive Pokemon Cards
# My Grandparents           XCOM
# The Dominion War (DS9)    Ultimate Frisbee
# Beyonce’s Cowboy Carter   Distributed Telescopic Networks
# Interstellar (movie)      Hozier’s ”Unreal Unearth”
# Dragons                   Star Trek
# Hamilton (musical)        Sonoluminescence
# Bucket List               Escape Rooms
# Astro 322 HW (3 papers)   Random Garbage (5 papers)

# %% [markdown]
# ---
#
# ## Due: Sunday Dec 7 at 5 pm
#
# * Upload the PDF to the class canvas site
#
# I am not going to look at/grade the assignments until the due date.
# So, no sending them back to you with comments to fix.
# You can resubmit as many times as you want before the deadline - I will look at the last submission.
#
# Of course, if you have any questions while you are working on the assignment - feel free to email me.
